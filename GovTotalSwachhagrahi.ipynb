# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanRKG/-Career-Aspirations-Analysis-of-Gen-Z/blob/main/GovTotalSwachhagrahi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np

# %%
inp=pd.read_csv('/content/bfccb323-c9d8-4e44-bcbb-570aa569b1e5.csv')
inp.head()
# Out:
#         StateName   DistrictName  TotalGramPanchayat  TotalSwachhagrahi  \
# 0  Andhra Pradesh     ANAKAPALLI                 0.0                297
# 1  Andhra Pradesh     ANAKAPALLI               600.0                297
# 2  Andhra Pradesh  Ananthapuramu                 0.0                  0
# 3  Andhra Pradesh      ANNAMAYYA               454.0                557
# 4  Andhra Pradesh        BAPATLA               451.0                533
#
#                     Date
# 0  9/14/2024 12:00:00 AM
# 1  9/14/2024 12:00:00 AM
# 2  9/14/2024 12:00:00 AM
# 3  9/14/2024 12:00:00 AM
# 4  9/14/2024 12:00:00 AM

# %%
inp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   StateName           1592 non-null   object
#  1   DistrictName        1592 non-null   object
#  2   TotalGramPanchayat  1588 non-null   float64
#  3   TotalSwachhagrahi   1592 non-null   int64
#  4   Date                1592 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 62.3+ KB

# %%
inp.describe()
# Out:
#        TotalGramPanchayat  TotalSwachhagrahi
# count         1588.000000        1592.000000
# mean           185.042821         563.941583
# std            278.914756         774.371973
# min              0.000000           0.000000
# 25%              0.000000          37.000000
# 50%             32.500000         318.000000
# 75%            299.000000         753.500000
# max           1849.000000        6374.000000

# %%
inp.isnull().sum()
# Out:
# StateName             0
# DistrictName          0
# TotalGramPanchayat    4
# TotalSwachhagrahi     0
# Date                  0
# dtype: int64

# %%
inp[inp['TotalGramPanchayat'].isnull()]
# Out:
#         StateName DistrictName  TotalGramPanchayat  TotalSwachhagrahi  \
# 621   West Bengal     SILIGURI                 NaN                  0
# 1183    Rajasthan      JODHPUR                 NaN                  0
# 1309   Chandigarh   CHANDIGARH                 NaN                  0
# 1495    Rajasthan       JAIPUR                 NaN                  0
#
#                        Date
# 621   9/14/2024 12:00:00 AM
# 1183  9/14/2024 12:00:00 AM
# 1309  9/14/2024 12:00:00 AM
# 1495  9/14/2024 12:00:00 AM

# %%
mean_TGP=inp['TotalGramPanchayat'].mean()
mean_TGP
# Out:
# 185.04282115869017

# %%
inp['TotalGramPanchayat'].fillna(mean_TGP,inplace=True)

# %%
inp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   StateName           1592 non-null   object
#  1   DistrictName        1592 non-null   object
#  2   TotalGramPanchayat  1588 non-null   float64
#  3   TotalSwachhagrahi   1592 non-null   int64
#  4   Date                1592 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 62.3+ KB

# %%
inp
# Out:
#            StateName       DistrictName  TotalGramPanchayat  \
# 0     Andhra Pradesh         ANAKAPALLI                 0.0
# 1     Andhra Pradesh         ANAKAPALLI               600.0
# 2     Andhra Pradesh      Ananthapuramu                 0.0
# 3     Andhra Pradesh          ANNAMAYYA               454.0
# 4     Andhra Pradesh            BAPATLA               451.0
# ...              ...                ...                 ...
# 1587     West Bengal        COOCH BEHAR                 0.0
# 1588     West Bengal            HOOGHLY                 0.0
# 1589     West Bengal           JHARGRAM                 0.0
# 1590     West Bengal  North 24 Parganas               199.0
# 1591     West Bengal  South 24 Parganas                 0.0
#
#       TotalSwachhagrahi                   Date
# 0                   297  9/14/2024 12:00:00 AM
# 1                   297  9/14/2024 12:00:00 AM
# 2                     0  9/14/2024 12:00:00 AM
# 3                   557  9/14/2024 12:00:00 AM
# ...

# %%
s='9/14/2024,12:00:00 AM'

# %%
s.split(',')[0]
# Out:
# '9/14/2024'

# %%
inp["Date"].str.split(',')[0][0]
# Out:
# '9/14/2024 12:00:00 AM'

# %%
inp["Date"].str.split(',').str[0]
# Out:
# 0       9/14/2024 12:00:00 AM
# 1       9/14/2024 12:00:00 AM
# 2       9/14/2024 12:00:00 AM
# 3       9/14/2024 12:00:00 AM
# 4       9/14/2024 12:00:00 AM
#                 ...
# 1587    9/14/2024 12:00:00 AM
# 1588    9/14/2024 12:00:00 AM
# 1589    9/14/2024 12:00:00 AM
# 1590    9/14/2024 12:00:00 AM
# 1591    9/14/2024 12:00:00 AM
# Name: Date, Length: 1592, dtype: object

# %%
inp0=inp.copy()
inp0
# Out:
#            StateName       DistrictName  TotalGramPanchayat  \
# 0     Andhra Pradesh         ANAKAPALLI                 0.0
# 1     Andhra Pradesh         ANAKAPALLI               600.0
# 2     Andhra Pradesh      Ananthapuramu                 0.0
# 3     Andhra Pradesh          ANNAMAYYA               454.0
# 4     Andhra Pradesh            BAPATLA               451.0
# ...              ...                ...                 ...
# 1587     West Bengal        COOCH BEHAR                 0.0
# 1588     West Bengal            HOOGHLY                 0.0
# 1589     West Bengal           JHARGRAM                 0.0
# 1590     West Bengal  North 24 Parganas               199.0
# 1591     West Bengal  South 24 Parganas                 0.0
#
#       TotalSwachhagrahi                   Date
# 0                   297  9/14/2024 12:00:00 AM
# 1                   297  9/14/2024 12:00:00 AM
# 2                     0  9/14/2024 12:00:00 AM
# 3                   557  9/14/2024 12:00:00 AM
# ...

# %%
inp0.shape[0]
# Out:
# 1592

# %%
inp0['TotalGramPanchayat'].isnull().sum()
# Out:
# 0

# %%
((inp0['TotalGramPanchayat'].isnull().sum())/(inp0.shape[0]))*100
# Out:
# 0.0

# %%
gtp=inp0['TotalGramPanchayat'].mode()[0]
gtp
# Out:
# 0.0

# %%
inp0['TotalSwachhagrahi'].isnull().sum()
# Out:
# 0

# %%
((inp0['TotalSwachhagrahi'].isnull().sum())/(inp0.shape[0]))*100
# Out:
# 0.0

# %%
ts=inp0['TotalSwachhagrahi'].mode()[0]
ts
# Out:
# 0

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(inp0['TotalGramPanchayat'])
# Out:
# (array([1042.,  234.,  161.,   70.,   38.,   18.,   17.,    6.,    3.,
#            3.]),
#  array([   0. ,  184.9,  369.8,  554.7,  739.6,  924.5, 1109.4, 1294.3,
#         1479.2, 1664.1, 1849. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(inp0['TotalSwachhagrahi'])
# Out:
# (array([1109.,  294.,  101.,   33.,   20.,   12.,   19.,    2.,    0.,
#            2.]),
#  array([   0. ,  637.4, 1274.8, 1912.2, 2549.6, 3187. , 3824.4, 4461.8,
#         5099.2, 5736.6, 6374. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(inp0['TotalGramPanchayat'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d455699c490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d455699c9d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d455699c1f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d455699cf10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d455699d1b0>],
#  'means': []}

# %%
plt.boxplot(inp0['TotalSwachhagrahi'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d4556a1c580>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d4556a1cac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d4556a1c2e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d4556a1d000>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d4556a1d2a0>],
#  'means': []}

# %%
inp0.columns
# Out:
# Index(['StateName', 'DistrictName', 'TotalGramPanchayat', 'TotalSwachhagrahi',
#        'Date'],
#       dtype='object')

# %%
inp0['StateName'].value_counts()
# Out:
# StateName
# Uttar Pradesh                   161
# Madhya Pradesh                  110
# Rajasthan                        92
# Bihar                            83
# Assam                            79
# Tamil Nadu                       74
# Maharashtra                      68
# Chhattisgarh                     67
# Gujarat                          66
# Telangana                        64
# Karnataka                        62
# Odisha                           60
# Andhra Pradesh                   55
# Arunachal Pradesh                52
# Jharkhand                        48
# West Bengal                      46
# Punjab                           46
# Haryana                          45
# Jammu & Kashmir                  40
# Himachal Pradesh                 37
# Nagaland                         35
# Manipur                          32
# Mizoram                          30
# Meghalaya                        30
# Kerala                           28
# Uttarakhand                      26
# ...

# %%
percentage_state=inp0['StateName'].value_counts(normalize=True)*100
percentage_state
# Out:
# StateName
# Uttar Pradesh                   10.113065
# Madhya Pradesh                   6.909548
# Rajasthan                        5.778894
# Bihar                            5.213568
# Assam                            4.962312
# Tamil Nadu                       4.648241
# Maharashtra                      4.271357
# Chhattisgarh                     4.208543
# Gujarat                          4.145729
# Telangana                        4.020101
# Karnataka                        3.894472
# Odisha                           3.768844
# Andhra Pradesh                   3.454774
# Arunachal Pradesh                3.266332
# Jharkhand                        3.015075
# West Bengal                      2.889447
# Punjab                           2.889447
# Haryana                          2.826633
# Jammu & Kashmir                  2.512563
# Himachal Pradesh                 2.324121
# Nagaland                         2.198492
# Manipur                          2.010050
# ...

# %%
percentage_state=inp0['TotalSwachhagrahi'].value_counts(normalize=True)*100
percentage_state
# Out:
# TotalSwachhagrahi
# 0       12.625628
# 1        1.381910
# 7        1.067839
# 37       1.005025
# 10       0.816583
#           ...
# 1969     0.062814
# 1766     0.062814
# 1369     0.062814
# 507      0.062814
# 631      0.062814
# Name: proportion, Length: 506, dtype: float64
